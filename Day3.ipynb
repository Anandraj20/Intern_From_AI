# %% [markdown]
# i=1
# while i<=5 :
#   print(i)
#     i

# %%
i=1

while i<=5 :
    print(i)
    i+=1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
num=int(input("Enter the Number"))
fact=1
i=1
while i <=num :
     fact =fact * i
     i=i+1
print("Factorial ",fact)
# Out:
# Enter the Number 5
# Factorial  120

# %%
password=""
while password!="1234" :
   password =input("Enter the Password : ")
print("Access Granted")
# Out:
# Enter the Password :  4567
# Enter the Password :  yui
# Enter the Password :  yuu788
# Enter the Password :  1234
# Access Granted

# %%
add=lambda a,b : a+b
print(add(2,2))
# Out:
# 4

# %%
nums=[1,2,3,4,]

result=list(map(lambda x : x * 3,nums))
print(result)
# Out:
# [3, 6, 9, 12]

# %%
nums=[1,2,3,4,5,6,7,8]
even=list(filter(lambda x : x%2==0,nums))
print(even)
# Out:
# [2, 4, 6, 8]

# %%
nums=[2,4,6,8]
print(all(x%2==0 for x in nums))
# Out:
# True

# %%
nums=[1,2,3,4]
print(any(x%2==0 for x in nums
         ))
# Out:
# True
